# %%
#print is usd to in built function that is used to show output 
print("hello world")
# Out:
# hello world

# %%
print(5)
# Out:
# 5

# %%
print("Bye")
# Out:
# Bye

# %%
print("17*13")
# Out:
# 17*13

# %%
print(17*13)
# Out:
# 221

# %%
'''escape sequences & print statement 
hey priyanshi ,u are  gonna learn python in 20 days with consistency'''
#here above this triple single code, or triple  double code  is used for multi line comment 
print("hey i am a good gurl\nand this viewer is also a good gurl")
#here \n is used for new line 
print(" hey, i am a \"good gurl\"\nand the viewer is also a good gurl ")
#here \' ,\" is a single character and can be used
# Out:
# hey i am a good gurl
# and this viewer is also a good gurl
#  hey, i am a "good gurl"
# and the viewer is also a good gurl

# %%
#this is a single - line comment 
print("hello world!!!") #printing hello world
# Out:
# hello world!!!

# %%
print("hey",6,7)
print ("hey", 6, 7, sep="~")
#here sep is used to give output like this or make it seem like join in one single line
print ("hey", 6, 7, sep="~", end = "009\n")
# end operator is used to print after the print statement
# Out:
# hey 6 7
# hey~6~7
# hey~6~7009
