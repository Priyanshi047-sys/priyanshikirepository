# %%
#variable and data types 
''' variables are like containers that hold data  '''

# %%
a = 123
print(a)
b = "shivam"# strings should be inside doule codes or error 
print(b)
# Out:
# 123
# shivam

# %%
'''data types basically tells like it is int or float or string 
and we can not add or do mathematical thing between do different data types'''
a = 5
b = "life "
print (a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       3 a = 5
#       4 b = "life "
# ----> 5 print (a+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#since u can see the error coz of different data types 
a = 9
b=8088
print(a+b)
c = "priyanshi"
d = "shivam"
print(c+d)
# Out:
# 8097
# priyanshishivam

# %%
a =7
print("the type of a is ", type(a))
# Out:
# the type of a is  <class 'int'>

# %%
#sequenced data = list,tuple,dictionary 
#list is ordered collection of data in square brackets and separated by commas and they are mutable
list1 = [5,3.4,"apple"]
print(list1)
print("the type of list is",type(list1))
# Out:
# [5, 3.4, 'apple']
# the type of list is <class 'list'>

# %%
#tuple is same as list itz just it is immutable and parenthesis
tuple1 = ( "apple", 4,3,4.55)
print(tuple1)
print("the type of tuple1 is :",type(tuple1))
# Out:
# ('apple', 4, 3, 4.55)
# the type of tuple1 is : <class 'tuple'>

# %%
# dictionary is like key value pair under curly braces separarted by commas 
dict1 = {"name":"priyanshi","age ": 20 }
print(dict1)
print("the type of dict 1 is : ",type(dict1))
# Out:
# {'name': 'priyanshi', 'age ': 20}
# the type of dict 1 is :  <class 'dict'>

# %%
#operators 
print(5+98)
print(67-98)
print(8*7)
print(34/12)
print(34//12)#floor divison = ground value
print(12%5)#modulo = remainder
print(6**6)#power
# Out:
# 103
# -31
# 56
# 2.8333333333333335
# 2
# 2
# 46656

# %%
a = 9
b=7
addition = a+b
print(" addition of a and b : ", addition)
subtraction = a-b
print("subraction of a and b : ",subtraction)
multiplication = a*b
print(" multiplication of a and b : ", multiplication)
division = a/b
print("divison of and b :", division)
floor divison = a//b
print(" floor divison of a and b : ", floor divison)
modulus = a%b
print (" modulus of a and b is : ", modulus )
exponential = a**b
print(" exponential of a : ", exponential)
# Out:
#   Cell In[26], line 11
#     floor divison = a//b
#           ^
# SyntaxError: invalid syntax

# %%
a = 9
b=7
addition = a+b
print(" addition of a and b : ", addition)
subtraction = a-b
print("subraction of a and b : ",subtraction)
multiplication = a*b
print(" multiplication of a and b : ", multiplication)
division = a/b
print("divison of and b :", division)
floor_divison = a//b   #variable doesnt contain space
print(" floor divison of a and b : ", floor_divison)
modulus = a%b
print (" modulus of a and b is : ", modulus )
exponential = a**b
print(" exponential of a : ", exponential)
# Out:
#  addition of a and b :  16
# subraction of a and b :  2
#  multiplication of a and b :  63
# divison of and b : 1.2857142857142858
#  floor divison of a and b :  1
#  modulus of a and b is :  2
#  exponential of a :  4782969
