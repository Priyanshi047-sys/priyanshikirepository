# %%
'''f-string =  formatted string just to make the code easy and put variables directly inside the string '''
#f"your text {variable}"
#normally
name = "Priyanshi"
age = 20

print("My name is", name, "and I am", age, "years old")

name = "Priyanshi"
age = 20#same thing but more easy 

print(f"My name is {name} and I am {age} years old")
# Out:
# My name is Priyanshi and I am 20 years old
# My name is Priyanshi and I am 20 years old

# %%
a = 5
b = 3

print(f"Sum = {a+b}")

print("Sum is {}".format(a+b))#old and correct method but f string is easy
# Out:
# Sum = 8
# Sum is 8

# %%
'''docstring = it is written just above the body of function and we use the attribute the 
we can print it ..differenece from comment is comment doesnt affect the output but docs tring can'''
def square(n):
    '''Takes in a number n 
    return square'''
    print(n**2)
square(5)
print(square.__doc__)#this is the attribute or variable inside that helps in printing doctring
# Out:
# 25
# Takes in a number n
# return square
