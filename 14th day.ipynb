# %%
'''short hand if else statements '''
# a small statement over the condition if - else
a = 330000
b = 3303
print("A") if a>b else print("=") if a==b else print("B")

c = 9 if a>b else 0 
print(c)
# result = value_if_true if condition else value_if_false
# the syntax would have more complex without this statement
# Out:
# A
# 9

# %%
'''enumerate function '''
#get the index and value of each element in the sequemce at the same time 
marks = [12,56,32,98,12,45,1,4]
for index,mark in enumerate(marks):
    print(mark)
    if(index == 3):
        print("Harry , awesome!")
# Out:
# 12
# 56
# 32
# 98
# Harry , awesome!
# 12
# 45
# 1
# 4

# %%
# changing the start index
fruits = ['apple','banana','mango']
for index , fruit in enumerate(fruits):
    print(f'{index+1}: {fruit}')
# Out:
# 1: apple
# 2: banana
# 3: mango
