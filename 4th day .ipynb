# %%
#strings = words inside single or double quotes 
name = "Harry"
print(name)
print(name[0])#basically indexing of the word
# Out:
# Harry
# H

# %%
apple = ''' he said, hi priyanshi hey i am good 
" i want to eat an apple "'''
print(apple)
#inside triple codes we can write long strings
# Out:
#  he said, hi priyanshi hey i am good
# " i want to eat an apple "

# %%
print("letz use a for loop \n")
for character in apple : 
  print(character)
# Out:
# letz use a for loop
#
#
# h
# e
#
# s
# a
# i
# d
# ,
#
# h
# i
#
# p
# r
# i
# y
# a
# n
# s
# h
# i
#
# h
# e
# y
#
# i
#
# a
# m
#
# g
# o
# o
# d
#
#
#
# "
#
# i
#
# w
# a
# n
# t
#
# t
# o
#
# e
# a
# t
#
# a
# n
#
# a
# p
# p
# l
# e
#
# "

# %%
'''string slicing '''
names = "Shivam, Priyanshi"
print(names[0:5])# if we give ending 5 then it will print 4 letters 
print(names[0:8])#it even count the space as one 
#for slicing we use square brackets
# Out:
# Shiva
# Shivam,

# %%
#len is used to calculate the length of the string 
print(len(names))
# Out:
# 17

# %%
fruit = "mango"
len1=len(fruit)
print("Mango is a ",len1,"letter word.")
# Out:
# Mango is a  5 letter word.

# %%
fruit = "mango"
mangolen=len(fruit)
print(mangolen)#length print hoga
print(fruit[0:4])# 0 is included but not 4
print(fruit[1:5])#1 is included but not 5
print(fruit[:])# same as below 
print(fruit[:5])#automatically takes intial as 0
print(fruit[0:-3])#itz like length of string - 3 =5-3=2
print(fruit[-1:-3])# from 4 :2 it makes no sense thats why no ans 
print(fruit[-3:-1])
# Out:
# 5
# mang
# ango
# mango
# mango
# ma
#
# ng

# %%
'''string methods = operations on string '''
#upper lower
a = "priyanshi"
print(a)
print(a.upper())
print(a.lower())
# Out:
# priyanshi
# PRIYANSHI
# priyanshi

# %%
#rstrip
a ="shivam!!!"
print(len(a))
print(a.rstrip("!"))#it is so that we can strip the trailing characters at the end 
b = "!!shivam!!!"
print(len(b))
print(b.rstrip("!"))# it trails only of the ending not of the starting
# Out:
# 9
# shivam
# 11
# !!shivam

# %%
#replace
print(a.replace("shivam!!!","priyanshi"))#it replaces all the occurences of shivam by priyanshi 
print(a.replace("shivam","priyanshi"))
# Out:
# priyanshi
# priyanshi!!!

# %%
#split
c ="sharda university"
print(c.split(" "))
# Out:
# ['sharda', 'university']

# %%
#capitaize
d ="life is not that bad "
print(d.capitalize())# it capitalize the first alphabet of the word ..doesnt get affected if already capital 
e ="Life is not that bad "
print(e.capitalize())
# Out:
# Life is not that bad
# Life is not that bad

# %%
#count
f ="i m gonna have a happy life "
print(f.count("a"))#it counts the no. of times a specific string is repeated
# Out:
# 4

# %%
#endswith
f= "i m gonna have a happy life"
print(f.endswith("e"))#endswith return the value true or false if it is ending with that 
print(f.endswith("gonna",0,8))#we can even check the variables in between 
print(f.endswith("gonna",0,9))
# Out:
# True
# False
# True

# %%
#find = it is used to find the first occurence of the word if it is present it returns the index otherwise it returns -1
f= "i m gonna have a happy life"
print(f.find("have"))
print(f.find("itz"))
# Out:
# 10
# -1

# %%
#index = gives the index if not present then it raises exception 
print(f.index("have"))
print(f.index("itz"))
# Out:
# 10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 3
#       1 #index = gives the index if not present then it raises exception
#       2 print(f.index("have"))
# ----> 3 print(f.index("itz"))
#
# ValueError: substring not found

# %%
#isalnum + it turns true only if the entire string only consists of A-Z,a-z,0-9.if any other character s or punctuations are prsent then it returns false 
str1 = "Welcometotheconsole"
print(str1.isalnum())
str1 = "Welcome totheconsole"
print(str1.isalnum())
# Out:
# True
# False

# %%
#isalpha The isalnum() method returns True only if the entire string only consists of A-Z, a-z. If any other characters or punctuations or numbers(0-9) are present, then it returns False
str1 = "welcome"
print(str1.isalpha())
str1 = "welcome0"
print(str1.isalpha())
# Out:
# True
# False

# %%
#islower() + if all the characters in the string are lower ase , else it returns false 
str1 ="hello world "
print (str1.islower())
str1 ="hello worlD "
print (str1.islower())
# Out:
# True
# False

# %%
#isprintable() = method returns true if all the value within  the given string are printable , if not , returns false
str1 = "We wish you a Merry Christmas"
print(str1.isprintable())
str1 = "We wish you a Merry Christmas\n"
print(str1.isprintable())
# Out:
# True
# False

# %%
#The isspace() method returns True only and only if the string contains white spaces, else returns False.
str1 = "        "       #using Spacebar
print(str1.isspace())
str2 = "        "       #using Tab
print(str2.isspace())
str2 = ""       
print(str2.isspace())
# Out:
# True
# True
# False

# %%
#The istitile() returns True only if the first letter of each word of the string is capitalized, else it returns False.
str1 = "World Health Organization" 
print(str1.istitle())
# Out:
# True

# %%
#The isupper() method returns True if all the characters in the string are upper case, else it returns False.
str1 = "WORLD HEALTH ORGANIZATION" 
print(str1.isupper())
# Out:
# True

# %%
#startswith() = checks if the string starts with a given value. If yes then return True, else return False.
str1 = "Python is a Interpreted Language" 
print(str1.startswith("Python"))
# Out:
# True

# %%
#The swapcase() method changes the character casing of the string. Upper case are converted to lower case and lower case to upper case.
str1 = "Python is a Interpreted Language" 
print(str1.swapcase())
# Out:
# pYTHON IS A iNTERPRETED lANGUAGE

# %%
#The title() method capitalizes each letter of the word within the string.
str1 = "He's name is Dan. Dan is an honest man."
print(str1.title())
# Out:
# He'S Name Is Dan. Dan Is An Honest Man.
