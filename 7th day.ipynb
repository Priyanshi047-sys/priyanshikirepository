# %%
'''functions'''
def calculateGmean(a,b):# def is used to write before writing a function 
    mean = (a*b)/(a+b)
    print(mean)

a = 9
b = 8
if(a>b):
    print("First number is greater")
else:
    print("Second number is greter or equal")

calculateGmean(a,b)

c=8
d=7
if(a>b):
    print("First number is greater")
else:
    print("Second number is greter o equal")

calculateGmean(a,b)
# Out:
# First number is greater
# 4.235294117647059
# First number is greater
# 4.235294117647059

# %%
#default argument 
def average (a, b=1):
    print ("The average is ",(a+b)/2)

average(a=9)#in this it automatically took default value of a that is 9

#keyword argument = order does not matter 
average (b=8,a=6)

#Required argument = necessary to give argument 

#keyword arbitary argument 
def average (*numbers):
    sum = 0
    for i in numbers:
        sum = sum +i
    print("Average is : ",sum / len(numbers))

average(5,6,7,1)

def average (*numbers):
    sum = 0
    for i in numbers:
        sum = sum +i
    return sum / len(numbers)#return function 

average(5,6,7,1)
# Out:
# The average is  5.0
# The average is  7.0
# Average is :  4.75
# 4.75
